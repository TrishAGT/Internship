# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# calling libraries

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
df
#loading the data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.set_index('Happiness Rank', inplace=True)
df
# setting 'Happiness Rank' as index
# Out:
#                     Country                           Region  Happiness Score  \
# Happiness Rank
# 1               Switzerland                   Western Europe            7.587
# 2                   Iceland                   Western Europe            7.561
# 3                   Denmark                   Western Europe            7.527
# 4                    Norway                   Western Europe            7.522
# 5                    Canada                    North America            7.427
# ...                     ...                              ...              ...
# 154                  Rwanda               Sub-Saharan Africa            3.465
# 155                   Benin               Sub-Saharan Africa            3.340
# 156                   Syria  Middle East and Northern Africa            3.006
# 157                 Burundi               Sub-Saharan Africa            2.905
# 158                    Togo               Sub-Saharan Africa            2.839
#
# ...

# %%
df.head(15)
# top 15 ranking countries in the world
# Out:
#                       Country                           Region  \
# Happiness Rank
# 1                 Switzerland                   Western Europe
# 2                     Iceland                   Western Europe
# 3                     Denmark                   Western Europe
# 4                      Norway                   Western Europe
# 5                      Canada                    North America
# 6                     Finland                   Western Europe
# 7                 Netherlands                   Western Europe
# 8                      Sweden                   Western Europe
# 9                 New Zealand        Australia and New Zealand
# 10                  Australia        Australia and New Zealand
# 11                     Israel  Middle East and Northern Africa
# 12                 Costa Rica      Latin America and Caribbean
# 13                    Austria                   Western Europe
# 14                     Mexico      Latin America and Caribbean
# ...

# %%
# top 15 happiest countries shows 'Happiness Index' more than 7.

# %%
df.tail(15)

# lowest 15 ranking countries in the world
# Out:
#                                  Country                           Region  \
# Happiness Rank
# 144                                Niger               Sub-Saharan Africa
# 145                             Cambodia                Southeastern Asia
# 146                             Tanzania               Sub-Saharan Africa
# 147                           Madagascar               Sub-Saharan Africa
# 148             Central African Republic               Sub-Saharan Africa
# 149                                 Chad               Sub-Saharan Africa
# 150                               Guinea               Sub-Saharan Africa
# 151                          Ivory Coast               Sub-Saharan Africa
# 152                         Burkina Faso               Sub-Saharan Africa
# 153                          Afghanistan                    Southern Asia
# 154                               Rwanda               Sub-Saharan Africa
# ...

# %%
# Lowest 15 scoring countries have 'Happiness Score' between 2 and 4
# Al the 15 low scoring countries mostly belong to Sub-Saharan African region

# %%
value_region= df['Region'].value_counts().to_frame()
value_region
# Out:
#                                  Region
# Sub-Saharan Africa                   40
# Central and Eastern Europe           29
# Latin America and Caribbean          22
# Western Europe                       21
# Middle East and Northern Africa      20
# Southeastern Asia                     9
# Southern Asia                         7
# Eastern Asia                          6
# North America                         2
# Australia and New Zealand             2

# %%
(df.groupby('Region')['Happiness Score'].mean().sort_values(ascending=False)).to_frame()
# Out:
#                                  Happiness Score
# Region
# Australia and New Zealand               7.285000
# North America                           7.273000
# Western Europe                          6.689619
# Latin America and Caribbean             6.144682
# Eastern Asia                            5.626167
# Middle East and Northern Africa         5.406900
# Central and Eastern Europe              5.332931
# Southeastern Asia                       5.317444
# Southern Asia                           4.580857
# Sub-Saharan Africa                      4.202800

# %%
plt.figure(figsize=(30,10))
sns.boxplot(x="Region", y="Happiness Score", data=df, dodge=True)
plt.show()

# %%
df.shape
# the data contains 158 rows and 11 columns
# Out:
# (158, 11)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Score                158 non-null    float64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 14.8+ KB

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# Happiness Score                     Axes(0.125,0.53;0.110714x0.35)
# Standard Error                   Axes(0.257857,0.53;0.110714x0.35)
# Economy (GDP per Capita)         Axes(0.390714,0.53;0.110714x0.35)
# Family                           Axes(0.523571,0.53;0.110714x0.35)
# Health (Life Expectancy)         Axes(0.656429,0.53;0.110714x0.35)
# Freedom                          Axes(0.789286,0.53;0.110714x0.35)
# Trust (Government Corruption)       Axes(0.125,0.11;0.110714x0.35)
# Generosity                       Axes(0.257857,0.11;0.110714x0.35)
# Dystopia Residual                Axes(0.390714,0.11;0.110714x0.35)
# dtype: object

# %%
df.hist(bins=25,figsize=(10,10))
plt.show()

# %%
dfnew=df[(z<3).all(axis=1)]
print('dfnew.shape=',dfnew.shape)
# Out:
# dfnew.shape= (154, 11)

# %%
df=dfnew

# %%
df.skew()
# Out:
# Happiness Score                  0.145862
# Standard Error                   2.046188
# Economy (GDP per Capita)        -0.377668
# Family                          -0.782520
# Health (Life Expectancy)        -0.730171
# Freedom                         -0.400524
# Trust (Government Corruption)    1.273573
# Generosity                       0.997256
# Dystopia Residual               -0.204929
# dtype: float64

# %%
df['Trust (Government Corruption)'] = np.sqrt(df['Trust (Government Corruption)'])

# %%
df.skew()
# Out:
# Happiness Score                  0.145862
# Standard Error                   2.046188
# Economy (GDP per Capita)        -0.377668
# Family                          -0.782520
# Health (Life Expectancy)        -0.730171
# Freedom                         -0.400524
# Trust (Government Corruption)    0.424566
# Generosity                       0.997256
# Dystopia Residual               -0.204929
# dtype: float64

# %%
cor=df.corr()
cor
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.175881
# Standard Error                       -0.175881        1.000000
# Economy (GDP per Capita)              0.768388       -0.227554
# Family                                0.733202       -0.093808
# Health (Life Expectancy)              0.713364       -0.307807
# Freedom                               0.596402       -0.134096
# Trust (Government Corruption)         0.391177       -0.180215
# Generosity                            0.173556       -0.089872
# Dystopia Residual                     0.542652        0.081719
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.768388  0.733202
# Standard Error                                -0.227554 -0.093808
# Economy (GDP per Capita)                       1.000000  0.631635
# Family                                         0.631635  1.000000
# ...

# %%
sns.heatmap(cor)
# Out:
# <Axes: >

# %%
# GDP, family, health, freedom,Dyopia residual are highly corelated to 'Happiness score'
# Generosity is least related to 'Happiness Score'

# %%
cor['Happiness Score'].sort_values(ascending=False)
# Happiness score has highest correlation with Economy, Family, Health and freedom
# and has a least correlation with generosity
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.768388
# Family                           0.733202
# Health (Life Expectancy)         0.713364
# Freedom                          0.596402
# Dystopia Residual                0.542652
# Trust (Government Corruption)    0.391177
# Generosity                       0.173556
# Standard Error                  -0.175881
# Name: Happiness Score, dtype: float64

# %%
sns.lmplot(x="Happiness Score", y = 'Economy (GDP per Capita)', data = df)

# %%
sns.lmplot(x="Happiness Score", y = 'Family', data = df)

# %%
sns.lmplot(x="Happiness Score", y = 'Health (Life Expectancy)', data = df)

# %%
df.drop(['Generosity','Standard Error', 'Country', 'Region'], axis=1, inplace=True)

# %%
df
# Out:
#                 Happiness Score  Economy (GDP per Capita)   Family  \
# Happiness Rank
# 1                         7.587                   1.39651  1.34951
# 2                         7.561                   1.30232  1.40223
# 3                         7.527                   1.32548  1.36058
# 4                         7.522                   1.45900  1.33095
# 5                         7.427                   1.32629  1.32261
# ...                         ...                       ...      ...
# 152                       3.587                   0.25812  0.85188
# 153                       3.575                   0.31982  0.30285
# 155                       3.340                   0.28665  0.35386
# 156                       3.006                   0.66320  0.47489
# 157                       2.905                   0.01530  0.41587
#
#                 Health (Life Expectancy)  Freedom  \
# Happiness Rank
# 1                                0.94143  0.66557
# ...

# %%
x = df.drop(['Happiness Score'], axis = 1)
y = df['Happiness Score']

# %%
x
# Out:
#                 Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Happiness Rank
# 1                                1.39651  1.34951                   0.94143
# 2                                1.30232  1.40223                   0.94784
# 3                                1.32548  1.36058                   0.87464
# 4                                1.45900  1.33095                   0.88521
# 5                                1.32629  1.32261                   0.90563
# ...                                  ...      ...                       ...
# 152                              0.25812  0.85188                   0.27125
# 153                              0.31982  0.30285                   0.30335
# 155                              0.28665  0.35386                   0.31910
# 156                              0.66320  0.47489                   0.72193
# 157                              0.01530  0.41587                   0.22396
#
# ...

# %%
from sklearn import preprocessing
from sklearn import utils

lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y)

# %%
y.astype(int)
y
# Out:
# Happiness Rank
# 1      7.587
# 2      7.561
# 3      7.527
# 4      7.522
# 5      7.427
#        ...
# 152    3.587
# 153    3.575
# 155    3.340
# 156    3.006
# 157    2.905
# Name: Happiness Score, Length: 154, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import train_test_split

# %%
#MODELLING
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.30, random_state=i)
    RFR= RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred= RFR.predict(x_test)
    acc= accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu= acc
        maxRs= i
print('Best Accuracy is:',maxAccu, 'at random_state',maxRs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 10
#       8 x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.30, random_state=i)
#       9 RFR= RandomForestClassifier()
# ---> 10 RFR.fit(x_train,y_train)
#      11 pred= RFR.predict(x_test)
#      12 acc= accuracy_score(y_test, pred)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:385, in BaseForest.fit(self, X, y, sample_weight)
#     378         raise ValueError(
#     379             "Sum of y is not strictly positive which "
#     380             "is necessary for Poisson regression."
#     381         )
#     383 self.n_outputs_ = y.shape[1]
# --> 385 y, expanded_class_weight = self._validate_y_class_weight(y)
#     387 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#     388     y = np.ascontiguousarray(y, dtype=DOUBLE)
#
# ...
